# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
#Driver
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(options = options)

# %%
#Login page
login_url = "https://pe.computrabajo.com/login/"
driver.get(login_url)

# %%
#Login
input_email, *rest = driver.find_elements(By.CSS_SELECTOR, "#Email")
input_pass, *rest = driver.find_elements(By.CSS_SELECTOR, "#Password")

input_email.send_keys("info@japisale.com")
input_pass.send_keys("MilongoIV8")

btn, *rest = driver.find_elements(By.CSS_SELECTOR, "#bbR")
btn.click()

# %%
#Ir a Anuncio de empleo
driver.get("https://empresa.pe.computrabajo.com/Company/Offers/Match?oi=57776E486819C07761373E686DCF3405&cf=469814F59E4D6F04")

# %%
#Extraer los candidatos por página
_, *people_list = driver.find_elements(By.CSS_SELECTOR, "article.rowuser.pos_rel.bClick.no_icons")

# %%
# Receorrer cada candidato y estraer información básica
#for people in pople_list:
# first = people_list[0]

# %%
#people data
list_people = []
for people in people_list:
    name = people.find_element(By.CSS_SELECTOR, "ul li.nombre a").text
    try:
        image = people.find_element(By.CSS_SELECTOR, "ul li.nombre img.lazy").get_attribute("src")
    except:
        image = ""
    finally:
        profile_page = people.find_element(By.CSS_SELECTOR, "ul li.nombre a").get_attribute("href")
        application_time  = people.find_element(By.CSS_SELECTOR, "ul li.aplicado").text
        age = people.find_element(By.CSS_SELECTOR, "ul li.edad").text
        grade = people.find_element(By.CSS_SELECTOR, "ul li.estudios").text
        match = people.find_element(By.CSS_SELECTOR, "ul li.adecuacion p").text
        people_data = dict([
            ("name", name),
            ("image", image),
            ("profile_page", profile_page),
            ("application_time", application_time),
            ("age", age),
            ("grade", grade),
            ("match", match),
        ])
        list_people.append(people_data)

# %%
list_people
# Out:
# [{'name': 'Ana Paula Ana Paula Salinas',
#   'image': 'https://ii.ct-stc.com/3/logos/candidates/2023/07/24/151626thumbnail.jpeg',
#   'profile_page': 'https://empresa.pe.computrabajo.com/Company/MatchCvDetail/MatchDetail?oi=57776E486819C07761373E686DCF3405&ims=D8B698DB319BF00A4046D2A51DF2E93F&cf=469814F59E4D6F04',
#   'application_time': 'Hace 19 días',
#   'age': '26',
#   'grade': 'Universitario',
#   'match': '53 %'},
#  {'name': 'Carmen Musselmann',
#   'image': 'https://ii.ct-stc.com/3/logos/candidates/2023/05/02/213937thumbnail.jpeg',
#   'profile_page': 'https://empresa.pe.computrabajo.com/Company/MatchCvDetail/MatchDetail?oi=57776E486819C07761373E686DCF3405&ims=A692140A133D9AA9EC2456E4BF054B47&cf=469814F59E4D6F04',
#   'application_time': 'Hace 19 días',
#   'age': '44',
#   'grade': 'Maestría',
#   'match': '58 %'},
#  {'name': 'María Gracia Polar Argumedo',
#   'image': 'https://ii.ct-stc.com/3/logos/candidates/2023/08/24/205610thumbnail.jpeg',
#   'profile_page': 'https://empresa.pe.computrabajo.com/Company/MatchCvDetail/MatchDetail?oi=57776E486819C07761373E686DCF3405&ims=771446D7402FAF68F003EE19BB6AA99E&cf=469814F59E4D6F04',
#   'application_time': 'Hace 20 días',
#   'age': '22',
#   'grade': 'Técnico',
#   'match': '47 %'},
#  {'name': 'Julisa Leon corrales',
#   'image': 'https://ii.ct-stc.com/3/logos/candidates/2023/08/31/220923thumbnail.jpeg',
#   'profile_page': 'https://empresa.pe.computrabajo.com/Company/MatchCvDetail/MatchDetail?oi=57776E486819C07761373E686DCF3405&ims=99484980C157749C7E5CCE1038C1C049&cf=469814F59E4D6F04',
#   'application_time': 'Hace 22 días',
#   'age': '19',
#   'grade': 'Técnico',
#   'match': '47 %'},
#  {'name': 'Fernando Miguel Ponce Sanchez',
#   'image': 'https://ii.ct-stc.com/3/logos/candidates/2020/06/15/disenador-publicitario-93AE71ECDCAA9DD2144354thumbnail.jpeg',
#   'profile_page': 'https://empresa.pe.computrabajo.com/Company/MatchCvDetail/MatchDetail?oi=57776E486819C07761373E686DCF3405&ims=999D92F149F3F867353D49D7EAD31170&cf=469814F59E4D6F04',
#   'application_time': 'Hace 24 días',
#   'age': '33',
#   'grade': 'Técnico',
#   'match': '61 %'},
#  {'name': 'Lenyn Perez',
#   'image': 'https://ii.ct-stc.com/3/logos/candidates/2023/09/07/064133_disenador-web-0289786c401cc8a861373e686dcf3405thumbnail.jpg',
#   'profile_page': 'https://empresa.pe.computrabajo.com/Company/MatchCvDetail/MatchDetail?oi=57776E486819C07761373E686DCF3405&ims=8C67AE5A53C2923F91A06E28CCF39A9E&cf=469814F59E4D6F04',
#   'application_time': 'Hace 24 días',
#   'age': '20',
#   'grade': 'Sin especificar',
#   'match': '77 %'},
#  {'name': 'Rodrigo Aquije',
#   'image': 'https://ii.ct-stc.com/3/logos/candidates/2023/03/14/disenador-uxui-1AE73FCD7A454D2961373E686DCF3405205916thumbnail.jpeg',
#   'profile_page': 'https://empresa.pe.computrabajo.com/Company/MatchCvDetail/MatchDetail?oi=57776E486819C07761373E686DCF3405&ims=42108BD2114F6730729B5ABEB8365A48&cf=469814F59E4D6F04',
#   'application_time': 'Hace 25 días',
#   'age': '29',
#   'grade': 'Universitario',
#   'match': '52 %'},
#  {'name': 'Cesar Balarezo',
#   'image': '',
#   'profile_page': 'https://empresa.pe.computrabajo.com/Company/MatchCvDetail/MatchDetail?oi=57776E486819C07761373E686DCF3405&ims=A391CC058D2D04D19AC0454D5DB90301&cf=469814F59E4D6F04',
#   'application_time': 'Hace 25 días',
#   'age': '23',
#   'grade': 'Técnico',
#   'match': '44 %'},
#  {'name': 'Diana Carhuamanta Ibañez',
#   'image': 'https://ii.ct-stc.com/3/logos/candidates/2022/04/27/desarrollador-front-end-4E1C3DE3D590DF5C61373E686DCF3405011059thumbnail.jpeg',
#   'profile_page': 'https://empresa.pe.computrabajo.com/Company/MatchCvDetail/MatchDetail?oi=57776E486819C07761373E686DCF3405&ims=720FE3EEFE3E2C2D2C1710479D129131&cf=469814F59E4D6F04',
#   'application_time': 'Hace 26 días',
#   'age': '31',
#   'grade': 'Técnico',
#   'match': '52 %'},
#  {'name': 'Jose Manuel Mamani Barraza',
#   'image': 'https://ii.ct-stc.com/3/logos/candidates/2023/09/25/2253466089903thumbnail.jpeg',
#   'profile_page': 'https://empresa.pe.computrabajo.com/Company/MatchCvDetail/MatchDetail?oi=57776E486819C07761373E686DCF3405&ims=4A628EF0839AF6822E131014F4D8C902&cf=469814F59E4D6F04',
#   'application_time': 'Hace 26 días',
#   'age': '31',
#   'grade': 'Técnico',
#   'match': '51 %'},
#  {'name': 'Charlie Silva',
#   'image': 'https://ii.ct-stc.com/3/logos/candidates/2022/01/24/disenador-ux-ui-4E7CE52579E2988761373E686DCF3405223009thumbnail.jpeg',
#   'profile_page': 'https://empresa.pe.computrabajo.com/Company/MatchCvDetail/MatchDetail?oi=57776E486819C07761373E686DCF3405&ims=65E4131408C3F206A0719D2C43545EC6&cf=469814F59E4D6F04',
#   'application_time': 'Hace 26 días',
#   'age': '37',
#   'grade': 'Universitario',
#   'match': '52 %'},
#  {'name': 'Luis Dueñas',
#   'image': 'https://ii.ct-stc.com/3/logos/candidates/2023/08/03/220803thumbnail.jpeg',
#   'profile_page': 'https://empresa.pe.computrabajo.com/Company/MatchCvDetail/MatchDetail?oi=57776E486819C07761373E686DCF3405&ims=80F2A30C37F8A1E4A0719D2C43545EC6&cf=469814F59E4D6F04',
#   'application_time': 'Hace 27 días',
#   'age': '23',
#   'grade': 'Técnico',
#   'match': '16 %'},
#  {'name': 'Karina Milagros De la cruz',
#   'image': 'https://ii.ct-stc.com/3/logos/candidates/2021/09/01/disenadora-grafica-9422C631A6B6852E010129thumbnail.png',
#   'profile_page': 'https://empresa.pe.computrabajo.com/Company/MatchCvDetail/MatchDetail?oi=57776E486819C07761373E686DCF3405&ims=08160D89DD840BD7C41BEF05180029E6&cf=469814F59E4D6F04',
#   'application_time': 'Hace 27 días',
#   'age': '28',
#   'grade': 'Maestría',
#   'match': '53 %'},
#  {'name': 'Gianella Caramutti Frías',
#   'image': '',
#   'profile_page': 'https://empresa.pe.computrabajo.com/Company/MatchCvDetail/MatchDetail?oi=57776E486819C07761373E686DCF3405&ims=613F85DF10168AF9361EC43564CFF4A1&cf=469814F59E4D6F04',
#   'application_time': 'Hace 31 días',
#   'age': '25',
#   'grade': 'Universitario',
#   'match': '14 %'},
#  {'name': 'Abigail López Rojas',
#   'image': 'https://ii.ct-stc.com/3/logos/candidates/2023/01/24/disenador-grafico--2D559E4657F56FB261373E686DCF3405212722thumbnail.jpeg',
#   'profile_page': 'https://empresa.pe.computrabajo.com/Company/MatchCvDetail/MatchDetail?oi=57776E486819C07761373E686DCF3405&ims=E3009B3068D861327D1AF5614416819D&cf=469814F59E4D6F04',
#   'application_time': 'Hace 31 días',
#   'age': '21',
#   'grade': 'Universitario',
#   'match': '54 %'},
#  {'name': 'Lena Lizarraga',
#   'image': 'https://ii.ct-stc.com/3/logos/candidates/2022/05/29/disenador-grafico-A6E2AACA08D8E3AA61373E686DCF3405040703thumbnail.jpeg',
#   'profile_page': 'https://empresa.pe.computrabajo.com/Company/MatchCvDetail/MatchDetail?oi=57776E486819C07761373E686DCF3405&ims=8740EF1397140A02ACE3524FA3809F9D&cf=469814F59E4D6F04',
#   'application_time': 'Hace 33 días',
#   'age': '24',
#   'grade': 'Universitario',
#   'match': '52 %'},
#  {'name': 'Noelia Noelia Ramirez',
#   'image': 'https://ii.ct-stc.com/3/logos/candidates/2023/08/28/ux-designer-B3A9C01FEC98FC8361373E686DCF3405201920thumbnail.jpg',
#   'profile_page': 'https://empresa.pe.computrabajo.com/Company/MatchCvDetail/MatchDetail?oi=57776E486819C07761373E686DCF3405&ims=AB39C4275C4CD69E4046D2A51DF2E93F&cf=469814F59E4D6F04',
#   'application_time': 'Hace 33 días',
#   'age': '27',
#   'grade': 'Doctorado',
#   'match': '53 %'},
#  {'name': 'Halim Segovia',
#   'image': 'https://ii.ct-stc.com/3/logos/candidates/2021/06/29/163804_disenador-web-y-marketing-digital-055392de669f197a61373e686dcf3405thumbnail.jpg',
#   'profile_page': 'https://empresa.pe.computrabajo.com/Company/MatchCvDetail/MatchDetail?oi=57776E486819C07761373E686DCF3405&ims=F635F8BC3D62F6A7F003EE19BB6AA99E&cf=469814F59E4D6F04',
#   'application_time': 'Hace 33 días',
#   'age': '23',
#   'grade': 'Técnico',
#   'match': '54 %'},
#  {'name': 'Jerson Misael Lazo Amado',
#   'image': 'https://ii.ct-stc.com/3/logos/candidates/2022/07/23/38c039186dbe40fea977185317thumbnail.jpeg',
#   'profile_page': 'https://empresa.pe.computrabajo.com/Company/MatchCvDetail/MatchDetail?oi=57776E486819C07761373E686DCF3405&ims=E0F6BF9B6770723157D0F6FC0956AD79&cf=469814F59E4D6F04',
#   'application_time': 'Hace 34 días',
#   'age': '24',
#   'grade': 'Universitario',
#   'match': '53 %'},
#  {'name': 'Carlos Reyes',
#   'image': 'https://ii.ct-stc.com/3/logos/candidates/2023/05/03/174547thumbnail.jpeg',
#   'profile_page': 'https://empresa.pe.computrabajo.com/Company/MatchCvDetail/MatchDetail?oi=57776E486819C07761373E686DCF3405&ims=7F2C0EDBF93FD2C76D777C1B54B1F572&cf=469814F59E4D6F04',
#   'application_time': 'Hace 35 días',
#   'age': '23',
#   'grade': 'Técnico',
#   'match': '46 %'},
#  {'name': 'Alfonso Alexander Calagua Ortiz',
#   'image': '',
#   'profile_page': 'https://empresa.pe.computrabajo.com/Company/MatchCvDetail/MatchDetail?oi=57776E486819C07761373E686DCF3405&ims=A514188E7D4D358963A2C369ADA93754&cf=469814F59E4D6F04',
#   'application_time': 'Hace 36 días',
#   'age': '41',
#   'grade': 'Maestría',
#   'match': '20 %'},
#  {'name': 'Maria cecilia Stelluti',
#   'image': '',
#   'profile_page': 'https://empresa.pe.computrabajo.com/Company/MatchCvDetail/MatchDetail?oi=57776E486819C07761373E686DCF3405&ims=C12E51A0023341C4C65E842FB080910D&cf=469814F59E4D6F04',
#   'application_time': 'Hace 38 días',
#   'age': '26',
#   'grade': 'Universitario',
#   'match': '50 %'},
#  {'name': 'Paula Fernández',
#   'image': 'https://ii.ct-stc.com/3/logos/candidates/2023/08/24/143457thumbnail.png',
#   'profile_page': 'https://empresa.pe.computrabajo.com/Company/MatchCvDetail/MatchDetail?oi=57776E486819C07761373E686DCF3405&ims=D4F124A33F1705900E2ADCCCB1B190E1&cf=469814F59E4D6F04',
#   'application_time': 'Hace 38 días',
#   'age': '30',
#   'grade': 'Universitario',
#   'match': '53 %'},
#  {'name': 'Antuanet Medina',
#   'image': '',
#   'profile_page': 'https://empresa.pe.computrabajo.com/Company/MatchCvDetail/MatchDetail?oi=57776E486819C07761373E686DCF3405&ims=4586BE9211E46569A256EC30ED81B115&cf=469814F59E4D6F04',
#   'application_time': 'Hace 39 días',
#   'age': '21',
#   'grade': 'Técnico',
#   'match': '44 %'},
#  {'name': 'Sara Carpio cordova',
#   'image': 'https://ii.ct-stc.com/3/logos/candidates/2023/08/21/183932thumbnail.jpeg',
#   'profile_page': 'https://empresa.pe.computrabajo.com/Company/MatchCvDetail/MatchDetail?oi=57776E486819C07761373E686DCF3405&ims=E8EB894CB2A9486BC3E2005D13C2B8C2&cf=469814F59E4D6F04',
#   'application_time': 'Hace 40 días',
#   'age': '24',
#   'grade': 'Técnico',
#   'match': '53 %'},
#  {'name': 'Francisco gonzalo Calderon chavez',
#   'image': 'https://ii.ct-stc.com/3/logos/candidates/2020/05/16/disenador-grafico-C52B3B20C694C8E6215245thumbnail.jpeg',
#   'profile_page': 'https://empresa.pe.computrabajo.com/Company/MatchCvDetail/MatchDetail?oi=57776E486819C07761373E686DCF3405&ims=363BFB75DA39F7832E131014F4D8C902&cf=469814F59E4D6F04',
#   'application_time': 'Hace 40 días',
#   'age': '38',
#   'grade': 'Universitario',
#   'match': '53 %'},
#  {'name': 'Candy estefani Vargas deza',
#   'image': 'https://ii.ct-stc.com/3/logos/candidates/2020/12/24/disenadora-ui-BD521BCD984569AC61373E686DCF3405192039thumbnail.png',
#   'profile_page': 'https://empresa.pe.computrabajo.com/Company/MatchCvDetail/MatchDetail?oi=57776E486819C07761373E686DCF3405&ims=F34D5C94B5F75E3F3DDCBCAE8FE8E527&cf=469814F59E4D6F04',
#   'application_time': 'Hace 42 días',
#   'age': '33',
#   'grade': 'Técnico',
#   'match': '52 %'},
#  {'name': 'Ray Godoy Anicama',
#   'image': '',
#   'profile_page': 'https://empresa.pe.computrabajo.com/Company/MatchCvDetail/MatchDetail?oi=57776E486819C07761373E686DCF3405&ims=0A98402012108B2D7D1AF5614416819D&cf=469814F59E4D6F04',
#   'application_time': 'Hace 45 días',
#   'age': '41',
#   'grade': 'Técnico',
#   'match': '52 %'},
#  {'name': 'Claudia Loayza',
#   'image': 'https://ii.ct-stc.com/3/logos/candidates/2023/08/17/011044thumbnail.jpeg',
#   'profile_page': 'https://empresa.pe.computrabajo.com/Company/MatchCvDetail/MatchDetail?oi=57776E486819C07761373E686DCF3405&ims=11BD2AB42DB9075BCECD725AF2F20893&cf=469814F59E4D6F04',
#   'application_time': 'Hace 45 días',
#   'age': '24',
#   'grade': 'Técnico',
#   'match': '47 %'}]
